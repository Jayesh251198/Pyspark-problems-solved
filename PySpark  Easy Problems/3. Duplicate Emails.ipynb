# %% [markdown]
# ##  Duplicate Emails

# %% [markdown]
# ## Problem
#
# **Difficulty:** Easy
#
# **Topics**
#
# - SQL
#
# ---
#
# ## Table: `Person`
#
# | Column Name | Type |
# |-------------|------|
# | id | int |
# | email | varchar |
#
# - `id` is the primary key (column with unique values) for this table.
# - Each row of this table contains an email.
# - The emails will **not** contain uppercase letters.
#
# ---
#
# ## Task
#
# Write a solution to report all the duplicate emails.
#
# - It is guaranteed that the `email` field is **NOT NULL**.
# - Return the result table in **any order**.
#
# The result format is shown in the following example.
#
# ---
#
# ## Example 1
#
# ### Input
#
# ### Person
#
# | id | email |
# |----|---------|
# | 1 | a@b.com |
# | 2 | c@d.com |
# | 3 | a@b.com |
#
# ---
#
# ### Output
#
# | Email |
# |-------|
# | a@b.com |
#
# ---
#
# ### Explanation
#
# - The email **`a@b.com`** appears **2 times** in the `Person` table.
# - Since it is repeated more than once, it is considered a **duplicate email**.
# - The email **`c@d.com`** appears only once, so it is **not** included in the result.

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import StructType, StructField, IntegerType, StringType

# Start Spark session
spark = SparkSession.builder.appName("Databricks-PySpark-DF").getOrCreate()

# %% [markdown]
# ### 🔹 PySpark Table DataFrame

# %%
# Define schema
person_schema = StructType([
    StructField("id", IntegerType(), True),
    StructField("email", StringType(), True)
])

# Create data
person_data = [
    (1, "a@b.com"),
    (2, "c@d.com"),
    (3, "a@b.com")
]

# Create DataFrame
person_df = spark.createDataFrame(person_data, schema=person_schema)

print("Person Table:")
display(person_df)

# %% [markdown]
# ### 🔹 Logic Section

# %%
duplicates_emails_df = (person_df.groupBy("email").agg(count("*").alias("emails_counts"))
                                .filter(col("emails_counts") > 1)
                                .select("email"))
display(duplicates_emails_df)
